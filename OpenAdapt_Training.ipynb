# %%
# %cd /content
# !rm -rf adaptive-meta-env
# !git clone https://github.com/rithunkp/adaptive-meta-env.git
# %cd /content/adaptive-meta-env
# !git log --oneline -n 1
# Out:
# /content
# Cloning into 'adaptive-meta-env'...
# remote: Enumerating objects: 164, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 164 (delta 44), reused 133 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (164/164), 1015.85 KiB | 3.83 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# /content/adaptive-meta-env
# a8acaef (HEAD -> main, origin/main, origin/HEAD) Fix Colab GRPO compatibility for Unsloth + Transformers

# %%
# %cd /content/adaptive-meta-env
# !python -m unittest discover -s tests -p "test_openenv_incident_triage.py" -v
# !cd envs/incident_triage && openenv validate --verbose
# Out:
# /content/adaptive-meta-env
# test_malformed_raw_response_penalized (test_openenv_incident_triage.OpenEnvIncidentTriageTests.test_malformed_raw_response_penalized) ... ok
# test_reset_hides_ground_truth (test_openenv_incident_triage.OpenEnvIncidentTriageTests.test_reset_hides_ground_truth) ... ok
# test_string_params_are_parsed (test_openenv_incident_triage.OpenEnvIncidentTriageTests.test_string_params_are_parsed) ... ok
# test_valid_action_returns_reward_metadata (test_openenv_incident_triage.OpenEnvIncidentTriageTests.test_valid_action_returns_reward_metadata) ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.001s
#
# OK
# [OK] incident_triage: Ready for multi-mode deployment
#
# Supported deployment modes:
#   [YES] docker
#   [YES] openenv_serve
#   [YES] uv_run
#   [YES] python_module
#
# Usage examples:
#   cd incident_triage && uv run server
#   cd incident_triage && openenv build
#   cd incident_triage && openenv push

# %%
import os
from google.colab import userdata
os.environ["WANDB_API_KEY"] = userdata.get("WANDB_API_KEY")
os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")

# %%
# %cd /content/adaptive-meta-env
# !python hf_space_trainer.py \
  --model-name meta-llama/Llama-3.1-8B-Instruct \
  --max-steps 10 \
  --learning-rate 1e-5 \
  --output-dir artifacts/grpo_smoke \
  --final-model-dir artifacts/final_smoke \
  --run-name openadapt-smoke-test \
  --env-path generated_envs/incident_triage_env.py \
  --env-class IncidentTriageEnv
# Out:
# /content/adaptive-meta-env
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# Loading generated env 'IncidentTriageEnv' from generated_envs/incident_triage_env.py
# ENV_REGISTRY now has 4 environments.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: shahirabdulnazar2003 (shahirabdulnazar2003-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.1
# wandb: Run data is saved locally in /content/adaptive-meta-env/wandb/run-20260426_045841-v7893i99
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run openadapt-smoke-test
# wandb: ⭐️ View project at https://wandb.ai/shahirabdulnazar2003-/openenv-grpo
# wandb: 🚀 View run at https://wandb.ai/shahirabdulnazar2003-/openenv-grpo/runs/v7893i99
# Building trainer for meta-llama/Llama-3.1-8B-Instruct — 10 steps…
# /content/adaptive-meta-env/hf_space_trainer.py:265: UserWarning: WARNING: Unsloth should be imported before [transformers, peft] to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel, PatchFastRL
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: UnslothBCOTrainer is already patched.
# Unsloth: UnslothCPOTrainer is already patched.
# Unsloth: UnslothDPOTrainer is already patched.
# Unsloth: UnslothGKDTrainer is already patched.
# Unsloth: UnslothGRPOTrainer is already patched.
# Unsloth: UnslothKTOTrainer is already patched.
# Unsloth: UnslothNashMDTrainer is already patched.
# Unsloth: UnslothOnlineDPOTrainer is already patched.
# Unsloth: UnslothORPOTrainer is already patched.
# Unsloth: UnslothPPOTrainer is already patched.
# Unsloth: UnslothPRMTrainer is already patched.
# Unsloth: UnslothRewardTrainer is already patched.
# Unsloth: UnslothRLOOTrainer is already patched.
# Unsloth: UnslothSFTTrainer is already patched.
# Unsloth: UnslothXPOTrainer is already patched.
# ==((====))==  Unsloth 2026.4.8: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights: 100% 291/291 [00:24<00:00, 11.81it/s]
# config.json: 1.55kB [00:00, 900kB/s]
# tokenizer_config.json: 55.5kB [00:00, 61.2MB/s]
# tokenizer.json: 100% 17.2M/17.2M [00:00<00:00, 27.3MB/s]
# special_tokens_map.json: 100% 454/454 [00:00<00:00, 538kB/s]
# Unsloth: Will load unsloth/llama-3.1-8b-instruct-unsloth-bnb-4bit as a legacy tokenizer.
# Unsloth 2026.4.8 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.
# Training started.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 80 | Num Epochs = 1 | Total steps = 10
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 8 x 1) = 8
#  "-____-"     Trainable parameters = 41,943,040 of 8,072,204,288 (0.52% trained)
#   0% 0/10 [00:00<?, ?it/s]Passing `generation_config` together with generation-related arguments=({'pad_token_id', 'cache_implementation', 'disable_compile'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# `use_return_dict` is deprecated! Use `return_dict` instead!
# Unsloth: Will smartly offload gradients to save VRAM!
# {'loss': '1.816e-08', 'grad_norm': '0.2387', 'learning_rate': '0', 'num_tokens': '2469', 'completions/mean_length': '253.6', 'completions/min_length': '237', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '237', 'completions/min_terminated_length': '237', 'completions/max_terminated_length': '237', 'rewards/reward_func/mean': '0.0625', 'rewards/reward_func/std': '0.1768', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.1125', 'reward_std': '0.2031', 'frac_reward_zero_std': '0', 'completion_length': '253.6', 'kl': '1.031e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.0125'}
#  10% 1/10 [02:33<23:05, 153.97s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# {'loss': '-2.384e-07', 'grad_norm': '0.2096', 'learning_rate': '1e-05', 'num_tokens': '4973', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.5', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0625', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.5625', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.113e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.025'}
#  20% 2/10 [04:02<15:22, 115.33s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '0', 'grad_norm': '0.1952', 'learning_rate': '8.889e-06', 'num_tokens': '7394', 'completions/mean_length': '247.6', 'completions/min_length': '189', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '189', 'completions/min_terminated_length': '189', 'completions/max_terminated_length': '189', 'rewards/reward_func/mean': '0.0625', 'rewards/reward_func/std': '0.1768', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.1', 'reward_std': '0.169', 'frac_reward_zero_std': '0', 'completion_length': '247.6', 'kl': '1.222e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.0375'}
#  30% 3/10 [05:38<12:27, 106.81s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '4.47e-08', 'grad_norm': '0.2211', 'learning_rate': '7.778e-06', 'num_tokens': '9882', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.0625', 'rewards/reward_func/std': '0.1768', 'rewards/format_reward_func/mean': '0.025', 'rewards/format_reward_func/std': '0.04629', 'reward': '0.0875', 'reward_std': '0.1727', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.673e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.05'}
#  40% 4/10 [07:22<10:32, 105.35s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '3.725e-08', 'grad_norm': '0.3036', 'learning_rate': '6.667e-06', 'num_tokens': '1.237e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.0625', 'rewards/reward_func/std': '0.1768', 'rewards/format_reward_func/mean': '0.0125', 'rewards/format_reward_func/std': '0.03536', 'reward': '0.075', 'reward_std': '0.1753', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '2.174e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.0625'}
#  50% 5/10 [09:08<08:48, 105.63s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-3.874e-07', 'grad_norm': '0.1976', 'learning_rate': '5.556e-06', 'num_tokens': '1.487e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.5', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0125', 'rewards/format_reward_func/std': '0.03536', 'reward': '0.5125', 'reward_std': '0.03536', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '2.55e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.075'}
#  60% 6/10 [10:54<07:03, 105.81s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-1.639e-07', 'grad_norm': '0.193', 'learning_rate': '4.444e-06', 'num_tokens': '1.738e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.2375', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '2.319e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.0875'}
#  70% 7/10 [12:40<05:18, 106.06s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '0', 'grad_norm': '0.2374', 'learning_rate': '3.333e-06', 'num_tokens': '1.988e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.075', 'rewards/format_reward_func/std': '0.04629', 'reward': '0.275', 'reward_std': '0.04629', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '4.069e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.1'}
#  80% 8/10 [14:27<03:32, 106.37s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-1.788e-07', 'grad_norm': '0.2063', 'learning_rate': '2.222e-06', 'num_tokens': '2.239e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.025', 'rewards/format_reward_func/std': '0.04629', 'reward': '0.225', 'reward_std': '0.04629', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '4.249e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.1125'}
#  90% 9/10 [16:14<01:46, 106.34s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '4.172e-07', 'grad_norm': '0.2444', 'learning_rate': '1.111e-06', 'num_tokens': '2.489e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.5', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.5375', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '5.503e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.125'}
# 100% 10/10 [18:01<00:00, 106.60s/it]Unsloth: Restored added_tokens_decoder metadata in artifacts/grpo_smoke/checkpoint-10/tokenizer_config.json.
# {'train_runtime': '1083', 'train_samples_per_second': '0.074', 'train_steps_per_second': '0.009', 'train_loss': '-4.512e-08', 'epoch': '0.125'}
# 100% 10/10 [18:03<00:00, 108.31s/it]
# Done. Model saved to artifacts/final_smoke
# wandb:
# wandb: 🚀 View run openadapt-smoke-test at: https://wandb.ai/shahirabdulnazar2003-/openenv-grpo/runs/v7893i99
# wandb: Find logs at: wandb/run-20260426_045841-v7893i99/logs

# %%
# %cd /content/adaptive-meta-env
# !python hf_space_trainer.py \
  --model-name meta-llama/Llama-3.1-8B-Instruct \
  --max-steps 1200 \
  --learning-rate 1e-5 \
  --output-dir artifacts/grpo_main \
  --final-model-dir artifacts/final_main \
  --run-name openadapt-main \
  --env-path generated_envs/incident_triage_env.py \
  --env-class IncidentTriageEnv
# Out:
# /content/adaptive-meta-env
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cu128).
# Loading generated env 'IncidentTriageEnv' from generated_envs/incident_triage_env.py
# ENV_REGISTRY now has 4 environments.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: shahirabdulnazar2003 (shahirabdulnazar2003-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run 5o43feid (0.4s)
# wandb: Tracking run with wandb version 0.25.1
# wandb: Run data is saved locally in /content/adaptive-meta-env/wandb/run-20260426_052538-5o43feid
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run openadapt-main
# wandb: ⭐️ View project at https://wandb.ai/shahirabdulnazar2003-/openenv-grpo
# wandb: 🚀 View run at https://wandb.ai/shahirabdulnazar2003-/openenv-grpo/runs/5o43feid
# Building trainer for meta-llama/Llama-3.1-8B-Instruct — 1200 steps…
# /content/adaptive-meta-env/hf_space_trainer.py:265: UserWarning: WARNING: Unsloth should be imported before [transformers, peft] to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel, PatchFastRL
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: UnslothBCOTrainer is already patched.
# Unsloth: UnslothCPOTrainer is already patched.
# Unsloth: UnslothDPOTrainer is already patched.
# Unsloth: UnslothGKDTrainer is already patched.
# Unsloth: UnslothGRPOTrainer is already patched.
# Unsloth: UnslothKTOTrainer is already patched.
# Unsloth: UnslothNashMDTrainer is already patched.
# Unsloth: UnslothOnlineDPOTrainer is already patched.
# Unsloth: UnslothORPOTrainer is already patched.
# Unsloth: UnslothPPOTrainer is already patched.
# Unsloth: UnslothPRMTrainer is already patched.
# Unsloth: UnslothRewardTrainer is already patched.
# Unsloth: UnslothRLOOTrainer is already patched.
# Unsloth: UnslothSFTTrainer is already patched.
# Unsloth: UnslothXPOTrainer is already patched.
# ==((====))==  Unsloth 2026.4.8: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights: 100% 291/291 [00:15<00:00, 18.61it/s]
# Unsloth: Will load unsloth/llama-3.1-8b-instruct-unsloth-bnb-4bit as a legacy tokenizer.
# Unsloth 2026.4.8 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.
# Training started.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 9,600 | Num Epochs = 1 | Total steps = 1,200
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 8 x 1) = 8
#  "-____-"     Trainable parameters = 41,943,040 of 8,072,204,288 (0.52% trained)
#   0% 0/1200 [00:00<?, ?it/s]Passing `generation_config` together with generation-related arguments=({'pad_token_id', 'cache_implementation', 'disable_compile'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# `use_return_dict` is deprecated! Use `return_dict` instead!
# Unsloth: Will smartly offload gradients to save VRAM!
# {'loss': '1.816e-08', 'grad_norm': '0.2388', 'learning_rate': '0', 'num_tokens': '2469', 'completions/mean_length': '253.6', 'completions/min_length': '237', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '237', 'completions/min_terminated_length': '237', 'completions/max_terminated_length': '237', 'rewards/reward_func/mean': '0.0625', 'rewards/reward_func/std': '0.1768', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.1125', 'reward_std': '0.2031', 'frac_reward_zero_std': '0', 'completion_length': '253.6', 'kl': '1.031e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.0001042'}
#   0% 1/1200 [01:58<39:31:59, 118.70s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# {'loss': '-2.384e-07', 'grad_norm': '0.2096', 'learning_rate': '8.333e-08', 'num_tokens': '4973', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.5', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0625', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.5625', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.113e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.0002083'}
#   0% 2/1200 [03:46<37:22:01, 112.29s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '0', 'grad_norm': '0.1954', 'learning_rate': '1.667e-07', 'num_tokens': '7394', 'completions/mean_length': '247.6', 'completions/min_length': '189', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '189', 'completions/min_terminated_length': '189', 'completions/max_terminated_length': '189', 'rewards/reward_func/mean': '0.0625', 'rewards/reward_func/std': '0.1768', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.1', 'reward_std': '0.169', 'frac_reward_zero_std': '0', 'completion_length': '247.6', 'kl': '1.077e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.0003125'}
#   0% 3/1200 [05:33<36:34:41, 110.01s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-1.192e-07', 'grad_norm': '0.2144', 'learning_rate': '2.5e-07', 'num_tokens': '9898', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.25', 'reward_std': '0.05345', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.0004167'}
#   0% 4/1200 [07:20<36:06:26, 108.68s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '2.98e-08', 'grad_norm': '0.1946', 'learning_rate': '3.333e-07', 'num_tokens': '1.239e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0125', 'rewards/format_reward_func/std': '0.03536', 'reward': '0.0125', 'reward_std': '0.03536', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.105e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.0005208'}
#   0% 5/1200 [09:08<36:00:21, 108.47s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '2.98e-08', 'grad_norm': '0.2342', 'learning_rate': '4.167e-07', 'num_tokens': '1.487e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.125', 'rewards/reward_func/std': '0.2315', 'rewards/format_reward_func/mean': '0.0125', 'rewards/format_reward_func/std': '0.03536', 'reward': '0.1375', 'reward_std': '0.256', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.149e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.000625'}
#   0% 6/1200 [10:55<35:51:10, 108.10s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-1.341e-07', 'grad_norm': '0.2011', 'learning_rate': '5e-07', 'num_tokens': '1.736e+04', 'completions/mean_length': '254.1', 'completions/min_length': '241', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '241', 'completions/min_terminated_length': '241', 'completions/max_terminated_length': '241', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.25', 'reward_std': '0.05345', 'frac_reward_zero_std': '0', 'completion_length': '254.1', 'kl': '9.928e-06', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.0007292'}
#   1% 7/1200 [12:42<35:40:29, 107.65s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '0', 'grad_norm': '0.2229', 'learning_rate': '5.833e-07', 'num_tokens': '1.985e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.0375', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.129e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.0008333'}
#   1% 8/1200 [14:30<35:37:47, 107.61s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-1.49e-07', 'grad_norm': '0.2141', 'learning_rate': '6.667e-07', 'num_tokens': '2.236e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.2375', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.042e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.0009375'}
#   1% 9/1200 [16:17<35:32:41, 107.44s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '5.96e-08', 'grad_norm': '0.2319', 'learning_rate': '7.5e-07', 'num_tokens': '2.486e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.5', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.55', 'reward_std': '0.05345', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.217e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.001042'}
#   1% 10/1200 [18:04<35:30:29, 107.42s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '5.215e-08', 'grad_norm': '0.2443', 'learning_rate': '8.333e-07', 'num_tokens': '2.734e+04', 'completions/mean_length': '255.4', 'completions/min_length': '251', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '251', 'completions/min_terminated_length': '251', 'completions/max_terminated_length': '251', 'rewards/reward_func/mean': '0', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.05', 'reward_std': '0.05345', 'frac_reward_zero_std': '0', 'completion_length': '255.4', 'kl': '1.083e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.001146'}
#   1% 11/1200 [19:51<35:27:59, 107.38s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '3.651e-07', 'grad_norm': '0.1916', 'learning_rate': '9.167e-07', 'num_tokens': '2.985e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0875', 'rewards/format_reward_func/std': '0.03536', 'reward': '0.2875', 'reward_std': '0.03536', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.095e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.00125'}
#   1% 12/1200 [21:38<35:24:16, 107.29s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '6.706e-08', 'grad_norm': '0.214', 'learning_rate': '1e-06', 'num_tokens': '3.232e+04', 'completions/mean_length': '251.9', 'completions/min_length': '223', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '223', 'completions/min_terminated_length': '223', 'completions/max_terminated_length': '223', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0125', 'rewards/format_reward_func/std': '0.03536', 'reward': '0.2125', 'reward_std': '0.03536', 'frac_reward_zero_std': '0', 'completion_length': '251.9', 'kl': '1.046e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.001354'}
#   1% 13/1200 [23:25<35:16:42, 106.99s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '2.98e-08', 'grad_norm': '0.208', 'learning_rate': '1.083e-06', 'num_tokens': '3.48e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0125', 'rewards/format_reward_func/std': '0.03536', 'reward': '0.0125', 'reward_std': '0.03536', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '9.936e-06', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.001458'}
#   1% 14/1200 [25:11<35:11:23, 106.82s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-2.086e-07', 'grad_norm': '0.1987', 'learning_rate': '1.167e-06', 'num_tokens': '3.728e+04', 'completions/mean_length': '252', 'completions/min_length': '224', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '224', 'completions/min_terminated_length': '224', 'completions/max_terminated_length': '224', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.025', 'rewards/format_reward_func/std': '0.04629', 'reward': '0.225', 'reward_std': '0.04629', 'frac_reward_zero_std': '0', 'completion_length': '252', 'kl': '1.068e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.001563'}
#   1% 15/1200 [26:57<35:04:22, 106.55s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '5.96e-08', 'grad_norm': '0.196', 'learning_rate': '1.25e-06', 'num_tokens': '3.976e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.0625', 'rewards/reward_func/std': '0.1768', 'rewards/format_reward_func/mean': '0.025', 'rewards/format_reward_func/std': '0.04629', 'reward': '0.0875', 'reward_std': '0.1727', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.208e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.001667'}
#   1% 16/1200 [28:43<35:00:06, 106.42s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-3.129e-07', 'grad_norm': '0.2112', 'learning_rate': '1.333e-06', 'num_tokens': '4.227e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0625', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.2625', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.06e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.001771'}
#   1% 17/1200 [30:30<34:59:41, 106.49s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-1.639e-07', 'grad_norm': '0.1976', 'learning_rate': '1.417e-06', 'num_tokens': '4.473e+04', 'completions/mean_length': '250.4', 'completions/min_length': '227', 'completions/max_length': '256', 'completions/clipped_ratio': '0.75', 'completions/mean_terminated_length': '233.5', 'completions/min_terminated_length': '227', 'completions/max_terminated_length': '240', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.2375', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '250.4', 'kl': '1.104e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.001875'}
#   2% 18/1200 [32:18<35:06:15, 106.92s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '2.98e-08', 'grad_norm': '0.1818', 'learning_rate': '1.5e-06', 'num_tokens': '4.723e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0125', 'rewards/format_reward_func/std': '0.03536', 'reward': '0.2125', 'reward_std': '0.03536', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.04e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.001979'}
#   2% 19/1200 [34:05<35:06:48, 107.03s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '4.47e-08', 'grad_norm': '0.2015', 'learning_rate': '1.583e-06', 'num_tokens': '4.972e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.125', 'rewards/reward_func/std': '0.2315', 'rewards/format_reward_func/mean': '0.025', 'rewards/format_reward_func/std': '0.04629', 'reward': '0.15', 'reward_std': '0.2204', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.128e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.002083'}
#   2% 20/1200 [35:53<35:09:34, 107.27s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '0', 'grad_norm': '0.2207', 'learning_rate': '1.667e-06', 'num_tokens': '5.221e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.0375', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.183e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.002188'}
#   2% 21/1200 [37:40<35:07:30, 107.25s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-1.192e-07', 'grad_norm': '0.1923', 'learning_rate': '1.75e-06', 'num_tokens': '5.471e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.25', 'reward_std': '0.05345', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.157e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.002292'}
#   2% 22/1200 [39:27<35:02:28, 107.09s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '3.725e-07', 'grad_norm': '0.2235', 'learning_rate': '1.833e-06', 'num_tokens': '5.719e+04', 'completions/mean_length': '253.2', 'completions/min_length': '234', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '234', 'completions/min_terminated_length': '234', 'completions/max_terminated_length': '234', 'rewards/reward_func/mean': '0.5', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.5375', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '253.2', 'kl': '1.204e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.002396'}
#   2% 23/1200 [41:13<34:56:29, 106.87s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '3.651e-07', 'grad_norm': '0.2024', 'learning_rate': '1.917e-06', 'num_tokens': '5.964e+04', 'completions/mean_length': '249', 'completions/min_length': '200', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '200', 'completions/min_terminated_length': '200', 'completions/max_terminated_length': '200', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0875', 'rewards/format_reward_func/std': '0.03536', 'reward': '0.2875', 'reward_std': '0.03536', 'frac_reward_zero_std': '0', 'completion_length': '249', 'kl': '1.122e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.0025'}
#   2% 24/1200 [42:59<34:50:53, 106.68s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-1.788e-07', 'grad_norm': '0.2002', 'learning_rate': '2e-06', 'num_tokens': '6.215e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.025', 'rewards/format_reward_func/std': '0.04629', 'reward': '0.225', 'reward_std': '0.04629', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.136e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.002604'}
#   2% 25/1200 [44:46<34:48:13, 106.63s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '4.023e-07', 'grad_norm': '0.2075', 'learning_rate': '2.083e-06', 'num_tokens': '6.465e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.5', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.5375', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.375e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.002708'}
#   2% 26/1200 [46:32<34:44:46, 106.55s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-3.129e-07', 'grad_norm': '0.2007', 'learning_rate': '2.167e-06', 'num_tokens': '6.715e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0625', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.2625', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.494e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.002812'}
#   2% 27/1200 [48:18<34:39:14, 106.36s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-3.763e-07', 'grad_norm': '0.2137', 'learning_rate': '2.25e-06', 'num_tokens': '6.957e+04', 'completions/mean_length': '244.5', 'completions/min_length': '164', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '164', 'completions/min_terminated_length': '164', 'completions/max_terminated_length': '164', 'rewards/reward_func/mean': '0.5', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0125', 'rewards/format_reward_func/std': '0.03536', 'reward': '0.5125', 'reward_std': '0.03536', 'frac_reward_zero_std': '0', 'completion_length': '244.5', 'kl': '1.685e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.002917'}
#   2% 28/1200 [50:05<34:41:14, 106.55s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-1.192e-07', 'grad_norm': '0.2139', 'learning_rate': '2.333e-06', 'num_tokens': '7.207e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.25', 'reward_std': '0.05345', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '1.695e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.003021'}
#   2% 29/1200 [51:52<34:40:34, 106.60s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '5.215e-08', 'grad_norm': '0.3376', 'learning_rate': '2.417e-06', 'num_tokens': '7.444e+04', 'completions/mean_length': '239.5', 'completions/min_length': '124', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '124', 'completions/min_terminated_length': '124', 'completions/max_terminated_length': '124', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0125', 'rewards/format_reward_func/std': '0.03536', 'reward': '0.2125', 'reward_std': '0.03536', 'frac_reward_zero_std': '0', 'completion_length': '239.5', 'kl': '1.713e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.003125'}
#   2% 30/1200 [53:39<34:39:37, 106.65s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '2.608e-08', 'grad_norm': '0.2073', 'learning_rate': '2.5e-06', 'num_tokens': '7.695e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0125', 'rewards/format_reward_func/std': '0.03536', 'reward': '0.2125', 'reward_std': '0.03536', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '2.169e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.003229'}
#   3% 31/1200 [55:25<34:37:52, 106.65s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '7.451e-08', 'grad_norm': '0.2224', 'learning_rate': '2.583e-06', 'num_tokens': '7.945e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.2375', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '2.988e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.003333'}
#   3% 32/1200 [57:12<34:34:15, 106.55s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '0', 'grad_norm': '0.2221', 'learning_rate': '2.667e-06', 'num_tokens': '8.188e+04', 'completions/mean_length': '248.4', 'completions/min_length': '195', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '195', 'completions/min_terminated_length': '195', 'completions/max_terminated_length': '195', 'rewards/reward_func/mean': '0', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.0375', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '248.4', 'kl': '2.299e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.003438'}
#   3% 33/1200 [58:59<34:34:39, 106.67s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '6.788e-08', 'grad_norm': '0.2319', 'learning_rate': '2.75e-06', 'num_tokens': '8.428e+04', 'completions/mean_length': '245.5', 'completions/min_length': '172', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '172', 'completions/min_terminated_length': '172', 'completions/max_terminated_length': '172', 'rewards/reward_func/mean': '0.0625', 'rewards/reward_func/std': '0.1768', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.1', 'reward_std': '0.169', 'frac_reward_zero_std': '0', 'completion_length': '245.5', 'kl': '3.392e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.003542'}
#   3% 34/1200 [1:00:45<34:28:35, 106.45s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-1.192e-07', 'grad_norm': '0.202', 'learning_rate': '2.833e-06', 'num_tokens': '8.678e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.25', 'reward_std': '0.05345', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '3.066e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.003646'}
#   3% 35/1200 [1:02:31<34:29:01, 106.56s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-2.012e-07', 'grad_norm': '0.2266', 'learning_rate': '2.917e-06', 'num_tokens': '8.925e+04', 'completions/mean_length': '251.4', 'completions/min_length': '219', 'completions/max_length': '256', 'completions/clipped_ratio': '0.875', 'completions/mean_terminated_length': '219', 'completions/min_terminated_length': '219', 'completions/max_terminated_length': '219', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.025', 'rewards/format_reward_func/std': '0.04629', 'reward': '0.225', 'reward_std': '0.04629', 'frac_reward_zero_std': '0', 'completion_length': '251.4', 'kl': '4.705e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.00375'}
#   3% 36/1200 [1:04:18<34:24:48, 106.43s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-1.639e-07', 'grad_norm': '0.1977', 'learning_rate': '3e-06', 'num_tokens': '9.176e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.0375', 'rewards/format_reward_func/std': '0.05175', 'reward': '0.2375', 'reward_std': '0.05175', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '4.239e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.003854'}
#   3% 37/1200 [1:06:04<34:24:20, 106.50s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-8.196e-08', 'grad_norm': '0.2082', 'learning_rate': '3.083e-06', 'num_tokens': '9.426e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.25', 'reward_std': '0.05345', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '5.497e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.003958'}
#   3% 38/1200 [1:07:50<34:20:13, 106.38s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-1.937e-07', 'grad_norm': '0.1913', 'learning_rate': '3.167e-06', 'num_tokens': '9.676e+04', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.025', 'rewards/format_reward_func/std': '0.04629', 'reward': '0.225', 'reward_std': '0.04629', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '6.348e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.004063'}
#   3% 39/1200 [1:09:37<34:17:30, 106.33s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-5.215e-08', 'grad_norm': '0.2231', 'learning_rate': '3.25e-06', 'num_tokens': '9.912e+04', 'completions/mean_length': '238', 'completions/min_length': '180', 'completions/max_length': '256', 'completions/clipped_ratio': '0.75', 'completions/mean_terminated_length': '184', 'completions/min_terminated_length': '180', 'completions/max_terminated_length': '188', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.25', 'reward_std': '0.05345', 'frac_reward_zero_std': '0', 'completion_length': '238', 'kl': '9.118e-05', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.004167'}
#   3% 40/1200 [1:11:24<34:19:36, 106.53s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-1.267e-07', 'grad_norm': '0.208', 'learning_rate': '3.333e-06', 'num_tokens': '1.016e+05', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.025', 'rewards/format_reward_func/std': '0.04629', 'reward': '0.225', 'reward_std': '0.04629', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '0.0001058', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.004271'}
#   3% 41/1200 [1:13:10<34:18:22, 106.56s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '-4.47e-08', 'grad_norm': '0.2152', 'learning_rate': '3.417e-06', 'num_tokens': '1.041e+05', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.25', 'reward_std': '0.05345', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '0.0001087', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.004375'}
#   4% 42/1200 [1:14:56<34:13:22, 106.39s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '2.384e-07', 'grad_norm': '0.2216', 'learning_rate': '3.5e-06', 'num_tokens': '1.066e+05', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.0625', 'rewards/reward_func/std': '0.1768', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.1125', 'reward_std': '0.1642', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '0.0001709', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.004479'}
#   4% 43/1200 [1:16:43<34:13:40, 106.50s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '1.043e-07', 'grad_norm': '0.2392', 'learning_rate': '3.583e-06', 'num_tokens': '1.091e+05', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.075', 'rewards/format_reward_func/std': '0.04629', 'reward': '0.275', 'reward_std': '0.04629', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '0.0001284', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.004583'}
#   4% 44/1200 [1:18:30<34:13:39, 106.59s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '3.725e-07', 'grad_norm': '0.2869', 'learning_rate': '3.667e-06', 'num_tokens': '1.116e+05', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.4375', 'rewards/reward_func/std': '0.1768', 'rewards/format_reward_func/mean': '0.075', 'rewards/format_reward_func/std': '0.04629', 'reward': '0.5125', 'reward_std': '0.1727', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '0.0001649', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.004687'}
#   4% 45/1200 [1:20:16<34:09:41, 106.48s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '0', 'grad_norm': '0.2143', 'learning_rate': '3.75e-06', 'num_tokens': '1.141e+05', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.05', 'rewards/format_reward_func/std': '0.05345', 'reward': '0.25', 'reward_std': '0.05345', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '0.0001405', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.004792'}
#   4% 46/1200 [1:22:02<34:03:51, 106.27s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# {'loss': '1.118e-07', 'grad_norm': '0.2047', 'learning_rate': '3.833e-06', 'num_tokens': '1.166e+05', 'completions/mean_length': '256', 'completions/min_length': '256', 'completions/max_length': '256', 'completions/clipped_ratio': '1', 'completions/mean_terminated_length': '0', 'completions/min_terminated_length': '0', 'completions/max_terminated_length': '0', 'rewards/reward_func/mean': '0.2', 'rewards/reward_func/std': '0', 'rewards/format_reward_func/mean': '0.025', 'rewards/format_reward_func/std': '0.04629', 'reward': '0.225', 'reward_std': '0.04629', 'frac_reward_zero_std': '0', 'completion_length': '256', 'kl': '0.0003666', 'clip_ratio/low_mean': '0', 'clip_ratio/low_min': '0', 'clip_ratio/high_mean': '0', 'clip_ratio/high_max': '0', 'clip_ratio/region_mean': '0', 'epoch': '0.004896'}
#   4% 47/1200 [1:23:48<34:04:14, 106.38s/it]Both `max_new_tokens` (=256) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Traceback (most recent call last):
#   File "/content/adaptive-meta-env/hf_space_trainer.py", line 403, in <module>
#     main()
#   File "/content/adaptive-meta-env/hf_space_trainer.py", line 393, in main
#     trainer.train()
#   File "/content/adaptive-meta-env/unsloth_compiled_cache/UnslothGRPOTrainer.py", line 84, in wrapper
#     output = f(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/unsloth/models/rl.py", line 144, in _unsloth_train_with_resume_guard
#     return original_train(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/trainer.py", line 1424, in train
#     return inner_training_loop(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 83, in _fast_inner_training_loop
#   File "/usr/local/lib/python3.12/dist-packages/transformers/trainer.py", line 1734, in _run_epoch
#     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 34, in _unsloth_training_step
#   File "/usr/local/lib/python3.12/dist-packages/trl/extras/profiling.py", line 98, in wrapper
#     return func(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/adaptive-meta-env/unsloth_compiled_cache/UnslothGRPOTrainer.py", line 2835, in _prepare_inputs
#     generation_batch = self._generate_and_score_completions(generation_batch)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/unsloth/models/rl.py", line 526, in wrapped
#     return original(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/adaptive-meta-env/unsloth_compiled_cache/UnslothGRPOTrainer.py", line 3235, in _generate_and_score_completions
#     ) = self._generate(prompts, images)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/adaptive-meta-env/unsloth_compiled_cache/UnslothGRPOTrainer.py", line 3166, in _generate
#     prompt_ids, completion_ids, logprobs, forward_kwargs = self._generate_single_turn(prompts, images)
#                                                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/adaptive-meta-env/unsloth_compiled_cache/UnslothGRPOTrainer.py", line 3142, in _generate_single_turn
#     prompt_completion_ids = unwrapped_model.generate(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/unsloth/models/rl.py", line 198, in generate_with_clone
#     out = original_generate(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/peft/peft_model.py", line 2048, in generate
#     outputs = self.base_model.generate(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py", line 2133, in unsloth_fast_generate
#     output = self._old_generate(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py", line 2543, in generate
#     result = decoding_method(
#              ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py", line 2805, in _sample
#     this_peer_finished = unfinished_sequences.max() == 0
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# wandb:
# wandb: 🚀 View run openadapt-main at: https://wandb.ai/shahirabdulnazar2003-/openenv-grpo/runs/5o43feid
# wandb: Find logs at: wandb/run-20260426_052538-5o43feid/logs
